# %% [markdown]
# Computing Basic Stats for Data Set 1 and Data Set 2 comparison

# %%
import pandas as pd

data1 = pd.read_csv("Solar_flare_RHESSI_2004_05.csv")
data2 = pd.read_csv("Solar_flare_RHESSI_2015_16.csv")

stats_df1 = data1.describe()
stats_df2 = data2.describe()


print("Dataset 1 statistics:")
print(stats_df1)
print()

print("Dataset 2 statistics:")
print(stats_df2)
# Out:
# Dataset 1 statistics:
#          duration.s      peak.c/s  total.counts    x.pos.asec    y.pos.asec  \
# count  17506.000000  17506.000000  1.750600e+04  17506.000000  17506.000000
# mean     496.869645    217.462984  4.407130e+05    -22.704673    -32.637667
# std      444.053104    851.793720  3.368383e+06    705.787329    209.143786
# min        8.000000      0.000000  2.300000e+01  -1004.000000   -974.000000
# 25%      212.000000     24.000000  2.236800e+04   -707.750000   -193.000000
# 50%      360.000000     46.000000  5.613600e+04   -117.000000    -91.000000
# 75%      624.000000    128.000000  1.787460e+05    726.000000    138.750000
# max     4444.000000  58605.000000  3.188848e+08    996.000000    986.000000
#
#              radial  active.region.ar          year         month  \
# count  17506.000000      17506.000000  17506.000000  17506.000000
# mean     686.495430        571.695190   2004.417343      6.193934
# std      268.852465        267.504881      0.493135      3.469627
# min        0.000000          0.000000   2004.000000      1.000000
# 25%      473.000000        564.000000   2004.000000      3.000000
# 50%      749.000000        656.000000   2004.000000      7.000000
# 75%      944.000000        742.000000   2005.000000      9.000000
# max     1015.000000        844.000000   2005.000000     12.000000
#
#                 day  energy.kev.i  energy.kev.f
# count  17506.000000  17506.000000  17506.000000
# mean      15.676225      7.710385     15.766194
# std        8.539161      6.360895     16.461625
# min        1.000000      6.000000     12.000000
# 25%        9.000000      6.000000     12.000000
# 50%       15.000000      6.000000     12.000000
# 75%       23.000000      6.000000     12.000000
# max       31.000000    300.000000    800.000000
#
# Dataset 2 statistics:
#          duration.s      peak.c/s  total.counts    x.pos.asec    y.pos.asec  \
# count  10779.000000  10779.000000  1.077900e+04  10779.000000  10779.000000
# mean     509.913350    193.244735  2.781930e+05      8.903609     12.717413
# std      432.229806    547.448666  1.285833e+06    723.140066    259.957454
# min        8.000000      0.000000  8.000000e+00  -1004.000000   -981.000000
# 25%      224.000000     28.000000  1.924800e+04   -732.000000   -215.000000
# 50%      384.000000     56.000000  5.289600e+04      3.000000     79.000000
# 75%      656.000000    144.000000  1.587120e+05    791.000000    221.000000
# max     3908.000000  23247.000000  6.814669e+07   1002.000000   1012.000000
#
#              radial  active.region.ar          year         month  \
# count  10779.000000      10779.000000  10779.000000  10779.000000
# mean     724.534743       1482.420169   2015.183969      5.203080
# std      256.739942       1153.736179      0.387477      3.230096
# min        3.000000          0.000000   2015.000000      1.000000
# 25%      527.000000          0.000000   2015.000000      2.000000
# 50%      808.000000       2297.000000   2015.000000      5.000000
# 75%      953.000000       2371.000000   2015.000000      7.000000
# max     1015.000000       2621.000000   2016.000000     12.000000
#
#                 day  energy.kev.i  energy.kev.f
# count  10779.000000  10779.000000  10779.000000
# mean      15.555803      9.288431     19.739122
# std        8.911365     11.660791     32.144486
# min        1.000000      6.000000     12.000000
# 25%        8.000000      6.000000     12.000000
# 50%       15.000000      6.000000     12.000000
# 75%       23.000000      6.000000     12.000000
# max       31.000000    300.000000    800.000000

# %% [markdown]
# Histogram for Frequency

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('Solar_flare_RHESSI_2004_05.csv')

df['date'] = pd.to_datetime(df[['year', 'month']].assign(DAY=1))

months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['month'] = pd.Categorical(df['date'].dt.month_name(), categories=months_order, ordered=True)

# plt.figure(figsize=(12, 6))
# colors = ['skyblue', 'salmon']
# years_order = sorted(df['date'].dt.year.unique())

# for i, year in enumerate(years_order):
#     data_year = df[df['date'].dt.year == year]
#     data_year['month'].value_counts().sort_index().plot(kind='bar', label=str(year), alpha=0.7, color=colors[i])

# plt.title('Histogram of Months')
# plt.xlabel('Month')
# plt.ylabel('Frequency')
# plt.legend(title='Year')
# plt.show()

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

colors = ['skyblue', 'salmon']
years_order = sorted(df['date'].dt.year.unique())

for i, year in enumerate(years_order):
    data_year = df[df['date'].dt.year == year]
    data_year['month'].value_counts().sort_index().plot(kind='bar', ax=axs[i], label=str(year), alpha=0.7, color=colors[i])
    
axs[0].set_title('Histogram of Months (2004)')
axs[0].set_xlabel('Month')
axs[0].set_ylabel('Frequency')

axs[1].set_title('Histogram of Months (2005)')
axs[1].set_xlabel('Month')
axs[1].set_ylabel('Frequency')

plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()
